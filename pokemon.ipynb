# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../Dirty/pokedataset.csv")
df.head()
df = df.iloc[0:150]
df=df[["id","Name", "Height(m)", "Weight{kg}", "HP", "Attack", "Defense", "Sp.Atk", "Sp.Def", "Type_1"]]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          150 non-null    int64
#  1   Name        150 non-null    object
#  2   Height(m)   150 non-null    float64
#  3   Weight{kg}  150 non-null    float64
#  4   HP          150 non-null    int64
#  5   Attack      150 non-null    int64
#  6   Defense     150 non-null    int64
#  7   Sp.Atk      150 non-null    int64
#  8   Sp.Def      150 non-null    int64
#  9   Type_1      150 non-null    object
# dtypes: float64(2), int64(6), object(2)
# memory usage: 11.8+ KB

# %%
df = df.rename(columns={'id': 'Esto_debe_SER_ID'})

# 1. Datos Faltantes (Error 1)
df.loc[7, 'HP'] = np.nan
df.loc[12, 'Attack'] = np.nan

# 2. Filas Duplicadas (Exactas) (Error 2) - Duplicar Charizard (fila 5)
df = pd.concat([df, df.loc[[5]]], ignore_index=True)

# 3. Filas Duplicadas (Parciales) (Error 3) - Duplicar Ivysaur (fila 1) y modificar
df = pd.concat([df, df.loc[[1]]], ignore_index=True)
df.loc[df.index[-1], 'Name'] = 'Ivysaur_Partial_Dup'
df.loc[df.index[-1], 'HP'] = 999.0 

df.loc[8, 'Weight{kg}'] = 5000.0

df.loc[1, 'Height(m)'] = df.loc[1, 'Height(m)'] * 1000


df.loc[2, 'Tipo_Principal'] = 'Grassindo no es grassindo'

df.loc[3, 'Tipo_Principal'] = 'Categoria_extra'

df.loc[10, 'Defense'] = '40'


df.loc[15, 'Sp.Atk'] = '$50'

# Guardar el nuevo dataset sucio
df.to_csv('Basico_sucio.csv', index=False)
